# %%
from pyspark.sql import SparkSession
from pyspark.sql.types import StructType, StructField, StringType
from pyspark.sql import Row

# Initialize SparkSession
spark = SparkSession.builder.master("local").appName("Modes of DataFrameReader").getOrCreate()

# Define the schema
schema = StructType([
    StructField("Emp_no", StringType(), True),
    StructField("Emp_name", StringType(), True),
    StructField("Department", StringType(), True),
])

# Create dataset with both valid and corrupt records
data = [
    ("101", "Murugan", "HealthCare"),
    ("Invalid Entry", "Description: Bad Record entry", None),
    ("102", "Kannan", "Finance"),
    ("103", "Mani", "IT"),
    ("Connection lost", "Description: Poor Connection", None),
    ("104", "Pavan", "HR"),
    ("Bad Record", "Description: Corrupt record", None)
]

# Create DataFrame from dataset
df = spark.createDataFrame(data, schema)

# Filter out malformed records
df_filtered = df.filter(df["Emp_no"].cast("int").isNotNull())

# Show the DataFrame
df_filtered.show()
# Out:
# 24/09/15 16:28:43 WARN Utils: Your hostname, BMMDVADHIKRAMM.local resolves to a loopback address: 127.0.0.1; using 10.106.27.73 instead (on interface en0)
# 24/09/15 16:28:43 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/09/15 16:28:43 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 24/09/15 16:28:44 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# +------+--------+----------+
# |Emp_no|Emp_name|Department|
# +------+--------+----------+
# |   101| Murugan|HealthCare|
# |   102|  Kannan|   Finance|
# |   103|    Mani|        IT|
# |   104|   Pavan|        HR|
# +------+--------+----------+
# ----------------------------------------
# Exception occurred during processing of request from ('127.0.0.1', 52304)
# ...

# %%
from pyspark.sql import SparkSession
from pyspark.sql.types import StructType, StructField, StringType, IntegerType
from pyspark.sql.functions import col, when

# Initialize SparkSession
spark = SparkSession.builder.master("local").appName("Modes of DataFrameReader").getOrCreate()

# Define the schema
schema = StructType([
    StructField("Emp_no", StringType(), True),
    StructField("Emp_name", StringType(), True),
    StructField("Department", StringType(), True),
])

# Create dataset with both valid and corrupt records
data = [
    ("101", "Murugan", "HealthCare"),
    ("Invalid Entry", "Description: Bad Record entry", None),
    ("102", "Kannan", "Finance"),
    ("103", "Mani", "IT"),
    ("Connection lost", "Description: Poor Connection", None),
    ("104", "Pavan", "HR"),
    ("Bad Record", "Description: Corrupt record", None)
]

# Create DataFrame from dataset
df = spark.createDataFrame(data, schema)

# Identify malformed records
df_malformed = df.filter(
    (col("Emp_no").cast("int").isNull()) | 
    (col("Emp_name").isNull()) | 
    (col("Department").isNull())
)

# Identify valid records
df_valid = df.filter(
    (col("Emp_no").cast("int").isNotNull()) & 
    (col("Emp_name").isNotNull()) & 
    (col("Department").isNotNull())
)

# Show the valid DataFrame
print("Valid Data:")
df_valid.show()

# Show the malformed DataFrame
print("Malformed Data:")
df_malformed.show()
# Out:
# Valid Data:
# +------+--------+----------+
# |Emp_no|Emp_name|Department|
# +------+--------+----------+
# |   101| Murugan|HealthCare|
# |   102|  Kannan|   Finance|
# |   103|    Mani|        IT|
# |   104|   Pavan|        HR|
# +------+--------+----------+
#
# Malformed Data:
# +---------------+--------------------+----------+
# |         Emp_no|            Emp_name|Department|
# +---------------+--------------------+----------+
# |  Invalid Entry|Description: Bad ...|      NULL|
# |Connection lost|Description: Poor...|      NULL|
# |     Bad Record|Description: Corr...|      NULL|
# +---------------+--------------------+----------+
# 24/09/15 17:12:26 WARN HeartbeatReceiver: Removing executor driver with no recent heartbeats: 228858 ms exceeds timeout 120000 ms
# 24/09/15 17:12:26 WARN SparkContext: Killing executors is not supported by current scheduler.
# 24/09/15 17:14:25 ERROR Inbox: Ignoring error
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# ...
